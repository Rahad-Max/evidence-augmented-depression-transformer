# %% [markdown]
# # 04 Transformer Training
#
# ## 1. Research Objective
# Describe the objective of this specific notebook.
#
# ## 2. Input
# What data or state goes into this step.
#
# ## 3. Method
# What algorithms, processes, or transformations are applied.
#
# ## 4. Output
# What is produced (e.g., models, processed data, figures).
#
# ## 5. Experimental Decisions
# Document any hyperparameters, architectures, or other choices.
#
# ## 6. Evaluation Metrics
# Metrics used to evaluate success at this stage.

# %%
import os
import sys

# Colab compatibility
if 'google.colab' in sys.modules:
    from google.colab import drive
    drive.mount('/content/drive')
    # Set this to the project path in your Google Drive
    PROJECT_ROOT = '/content/drive/MyDrive/evidence-augmented-depression-transformer'
else:
    PROJECT_ROOT = '../'

sys.path.append(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)
print(f"Working directory set to: {os.getcwd()}")
